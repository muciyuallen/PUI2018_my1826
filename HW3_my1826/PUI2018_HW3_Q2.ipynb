# %%
import pandas as pd

url = "https://data.cityofnewyork.us/api/views/kpav-sd4t/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(url)

# %%
import os

puidata = os.getenv('PUIDATA')
puidata
# Out:
# '/nfshome/my1826/PUIdata'

# %%
df.head(7)
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 0   87990    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 1   97899    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 2  102221  DEPT OF ENVIRONMENT PROTECTION     External               1
# 3  102221  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 4  114352  DEPT OF ENVIRONMENT PROTECTION     Internal               5
# 5  117261  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 6  117261  DEPT OF ENVIRONMENT PROTECTION     External               1
#
#                              Business Title             Civil Service Title  \
# 0                           Account Manager  CONTRACT REVIEWER (OFFICE OF L
# 1  EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT  ADMINISTRATIVE BUSINESS PROMOT
# 2                        Project Specialist  ENVIRONMENTAL ENGINEERING INTE
# 3                        Project Specialist  ENVIRONMENTAL ENGINEERING INTE
# ...

# %%
df_reduced = df.drop(df.keys()[0:10]|df.keys()[12:], axis = 1)
df_reduced.head(7)
# Out:
#    Salary Range From  Salary Range To
# 0            42405.0          65485.0
# 1            60740.0         162014.0
# 2            43349.0          52496.0
# 3            43349.0          52496.0
# 4           109850.0         109850.0
# 5            43349.0          52496.0
# 6            43349.0          52496.0

# %%
# %pylab inline
df_reduced.plot(x = "Salary Range From", y = "Salary Range To", kind = "scatter", title = 'NYC Salary Range Distribution')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Figure 1:
# This graph displays the distribution of salary range of jobs listed on NYC jobs. Some takeawys:
# 1) Most of the jobs have starting salary from 40000 to 100000.
# 2) Jobs with starting salary from 50000 to 80000 have largest salary range.

# %% [markdown]
# # Extra Credits

# %%
url = "https://data.cityofnewyork.us/resource/swhp-yxa4.json"
df = pd.read_json(url)
df_reduced = df[['salary_range_from', 'salary_range_to']]
df.head(8)
# Out:
#    __of_positions                             additional_information  \
# 0               1  Mayorâ€™s Office of Contract Services is an eq...
# 1              10
# 2               1  IN ORDER TO BE CONSIDERED FOR THIS POSITION CA...
# 3               1  **IMPORTANT NOTES TO ALL CANDIDATES:  Please n...
# 4               1
# 5               1
# 6               1
# 7               1
#
#                            agency  \
# 0  MAYORS OFFICE OF CONTRACT SVCS
# 1        DEPARTMENT OF CORRECTION
# 2    DEPARTMENT OF TRANSPORTATION
# 3   DEPT OF HEALTH/MENTAL HYGIENE
# 4    NYC EMPLOYEES RETIREMENT SYS
# 5    DEPARTMENT OF BUSINESS SERV.
# 6   DEPT OF DESIGN & CONSTRUCTION
# 7   DEPT OF DESIGN & CONSTRUCTION
#
#                                       business_title  \
# 0              Senior Analyst, Policy & Partnerships
# 1                                               Cook
# 2               Principal Administrative Associate I
# 3  Senior Program Evaluator, Brooklyn Neighborhoo...
# ...

# %%
df_reduced.head(8)
# Out:
#    salary_range_from  salary_range_to
# 0            55000.0          62315.0
# 1            34096.0          38528.0
# 2            42856.0          62779.0
# 3            78630.0          98820.0
# 4            85000.0          90000.0
# 5            85823.0         120000.0
# 6               13.5             17.9
# 7               13.5             17.9

# %%
df_reduced.plot(x = "salary_range_from", y = "salary_range_to", kind = "scatter", title = 'NYC Salary Range Distribution')

# %% [markdown]
# Figure 1:
# This graph displays the distribution of salary range of jobs listed on NYC jobs. Some takeawys:
# 1) Most of the jobs have starting salary from 40000 to 100000.
# 2) Jobs with starting salary from 50000 to 80000 have largest salary range.
